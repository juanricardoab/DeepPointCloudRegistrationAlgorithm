# %%
import os
from google.colab import drive
drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/Proyecto de grado-Extensión/Registro de Nubes/Registro de Nubes')
# !pwd
# Out:
# Mounted at /content/drive
# /content/drive/.shortcut-targets-by-id/1bUVmxKZXlCNnu4CbA53Po31b084HWCvL/Registro de Nubes

# %%
# !pip install torch

# %%
# !pip install torchfile
# Out:
# ...
#   Created wheel for torchfile: filename=torchfile-0.1.0-py3-none-any.whl size=5709 sha256=7a3f01784b7585c556d9df941c7b73716ddc0090af2e278ad88c92ba80cecfc9
#   Stored in directory: /root/.cache/pip/wheels/ac/5c/3a/a80e1c65880945c71fd833408cd1e9a8cb7e2f8f37620bb75b
# Successfully built torchfile
# ...

# %%
import torchfile

obj = torch.load('DCP/dcp_v2.t7', map_location=torch.device('cpu'))

# %%
type(obj)
# Out:
# collections.OrderedDict

# %%
import torch.nn as nn

class TempModel(nn.Module):
    def __init__(self):
        self.conv1 = nn.Conv2d(3, 5, (3, 3))
    def forward(self, inp):
        return self.conv1(inp)

# %%
model = TempModel()
model.load_state_dict(obj)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-4e97b8f4e49a> in <module>()
#       1
#       2
# ----> 3 model = TempModel()
#       4 model.load_state_dict(obj)
#
# <ipython-input-43-4f571773bf78> in __init__(self)
#       3 class TempModel(nn.Module):
#       4     def __init__(self):
# ----> 5         self.conv1 = nn.Conv2d(3, 5, (3, 3))
#       6     def forward(self, inp):
#       7         return self.conv1(inp)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in __setattr__(self, name, value)
#    1205                 if modules is None:
#    1206                     raise AttributeError(
# -> 1207                         "cannot assign module before Module.__init__() call")
#    1208                 remove_from(self.__dict__, self._parameters, self._buffers, self._non_persistent_buffers_set)
# ...

# %%
print(r)

# %%
# !pip install torch.utils.serialization
# Out:
# ERROR: Could not find a version that satisfies the requirement torch.utils.serialization (from versions: none)
# ERROR: No matching distribution found for torch.utils.serialization

# %%
import torch
from torch.utils.serialization import load_lua

x = load_lua('/DCP/dcp_v2.t7', long_size=8)
print(x)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-16-496e52007c9c> in <module>()
#       1 import torch
# ----> 2 from torch.utils.serialization import load_lua
#       3
#       4 x = load_lua('/DCP/dcp_v2.t7', long_size=8)
#       5 print(x)
#
# ModuleNotFoundError: No module named 'torch.utils.serialization'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
